# %%
import numpy as np # importing numpy library as np
import pandas as pd # importing pandas as pd

# %%
df = pd.read_csv('data.csv')  # reading the csv file stored in local

# %%
df.describe() # Describing the statisticsl information related to the dataframe
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
np.where(pd.isnull(df)) # Seeing if we have any null values in the dataframe 
# the where method will return the indeces of the null values
# Out:
# (array([ 17,  27,  91, 118, 141], dtype=int64),
#  array([3, 3, 3, 3, 3], dtype=int64))

# %%
df.iloc[17,:] # checking if we have any null values at the index we got in the above cell
# Out:
# Duration     45.0
# Pulse        90.0
# Maxpulse    112.0
# Calories      NaN
# Name: 17, dtype: float64

# %%
df = df.fillna(df.mean()) # Filling all the null values wit hthe mean of respective columns
df.iloc[17,:] # checking if the null values are fillled or not with the index with which we checked in the above cell
# Out:
# Duration     45.000000
# Pulse        90.000000
# Maxpulse    112.000000
# Calories    375.790244
# Name: 17, dtype: float64

# %%
df_derived = df[['Duration','Pulse']] # getting the required columns from the main dataframe
print('minimum') # printing the statement Minimum 
print(df_derived.min()) # Printing the minimumm value in the subset of the dataframe

print('maximum') # printing the statement maximum
print(df_derived.max())
print('count') # printing the statement count
print(df_derived.count())
print('mean') # printing the statement mean
print(df_derived.mean())
# Out:
# minimum
# Duration    15
# Pulse       80
# dtype: int64
# maximum
# Duration    300
# Pulse       159
# dtype: int64
# count
# Duration    169
# Pulse       169
# dtype: int64
# mean
# Duration     63.846154
# Pulse       107.461538
# dtype: float64

# %%
df_greater = df[df['Calories']<1000  ] #filtering the dataframe with calories less than 1000
df_lesser = df_greater[df_greater['Calories']> 500] # FIltering the filtered dataframe further with calories greater than 500
df_lesser # printing the filtered dataframe
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_pulse = df[df['Pulse']<100] # filtering the dataframe with pulse less than 100
df_calories = df_pulse[df_pulse['Calories']>500] # Filtering the filtered dataframe further with calories greater than 500
df_calories # printing the finally filtered dataframe
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = df[['Duration','Pulse','Calories']] # only selecting the columns as per given question 'Duration','Pulse','Calories'
df_modified  #printing the df_modified
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
del df['Maxpulse'] # Deleting the column Max pulse from the main dataframe
df # printing the main dataframe
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df['Calories'] = df['Calories'].astype('int') # typecasting the calories in the main dataframe to integer using astype
print(df['Calories'].dtype) # printing the datatype of the calories int the main dataframe
# Out:
# int32

# %%
df.plot.scatter(0, 2) # Plotting the Duration and Calories from the dataframe using pandas builtin function
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Calories'>

# %%
titanic_train = pd.read_csv("train.csv") # reading the titanic csv from the local 
titanic_train# printing the train_titanic dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_corr  = titanic_train[['Sex','Survived']] # taking sex and survived columns into seperate dataframe for calculation of correlation
df_corr
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
print(df_corr.corr()) # Calculating the correlation 
 # yes we need to use the column Survived in the titanic df as the correlation is equal to 1
# Out:
#           Survived
# Survived       1.0

# %%
from sklearn.metrics import confusion_matrix # importing confusion matrix 
from sklearn.metrics import classification_report # importing classification report 
from sklearn.model_selection import train_test_split # importing test train split

# %%
titanic_train['Sex'] = titanic_train['Sex'].replace(["female", "male"], [0, 1]) # replacing demale with 0 and male with 1 for calculational convinenace
titanic_train['Embarked'] = titanic_train['Embarked'].replace(['S', 'C', 'Q'], [1, 2, 3]) # replacing the values in Embarked column for calculational convinenace
matrix = titanic_train.corr() # getting the correlation of the dataframe
print(matrix) # printing the correlation matrix
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.036847 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.077221 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.369226  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.093254 -0.114631
# Age             0.036847 -0.077221 -0.369226  0.093254  1.000000 -0.308247
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.308247  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.189119  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096067  0.159651
# Embarked       -0.030555  0.108669  0.043835 -0.118593  0.012186 -0.060606
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658 -0.030555
# Survived     0.081629  0.257307  0.108669
# Pclass       0.018443 -0.549500  0.043835
# Sex         -0.245489 -0.182333 -0.118593
# ...

# %%
#Heatmap showing the correlation between variables
import seaborn as sns #importing seaborn 
import matplotlib.pyplot as plt # importing matplotlib 
sns.heatmap(matrix, annot=True, vmax=1, vmin=-1, center=0, cmap='vlag') # showing the correlation of different variables of the dataframe
plt.show() # command to show the plot

# %%
sns.histplot(data=titanic_train, x="Survived", hue="Sex") # Showing bar chart of ther survived and not survived count as per sex
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB # importing Gaussian model 
titanic_test = pd.read_csv('test.csv') # reading the test dataset 
titanic_train.dropna(axis=0,inplace=True) # dropping na values from train dataset

# %%
titanic_test = titanic_train['Sex'].replace(["female", "male"], [0, 1]) # replacing female with 0 and male with 1 for calculational convinenace
titanic_test['Emested'] = titanic_train['Embarked'].replace(['S', 'C', 'Q'], [1, 2, 3]) #replacing  the embarked with numericals for calculational convinenace
titanic_test.dropna(axis=0,inplace=True) # dropping the na values from the test dataeet

# %%
from sklearn.metrics import accuracy_score
model = GaussianNB() # giving the gausssain NB Model for training 
titanic_test.drop('PassengerId', axis=1, inplace=True)
# drop Survived column in train data as it is the target variable
titanic_train.drop('Survived', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\anaconda\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[139], line 3
#       1 from sklearn.metrics import accuracy_score
#       2 model = GaussianNB() # giving the gausssain NB Model for training
# ----> 3 titanic_test.drop('PassengerId', axis=1, inplace=True)
#       4 # drop Survived column in train data as it is the target variable
#       5 titanic_train.drop('Survived', axis=1, inplace=True)
#
# ...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import warnings
warnings.filterwarnings("ignore")

# a. read glass.csv file as a dataframe
glass_data = pd.read_csv('glass.csv')

# b. Use train_test_split to create training and testing part
# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(glass_data.drop('Type', axis=1), glass_data['Type'], test_size=0.3, random_state=42)

# implement Naïve Bayes method using scikit-learn library and Evaluate the model on testing part using score and classification_report
# Create a Gaussian Classifier
model = GaussianNB()

# Train the model using the training sets
model.fit(X_train, y_train)

# Predict the response for test dataset
y_pred = model.predict(X_test)

# Calculate the accuracy of the model
print("Accuracy of the Naive Bayes model: ", accuracy_score(y_test, y_pred))

# Print classification report
print('Classification Report for Naive Bayes model: ')
print(classification_report(y_test, y_pred))


# Use SVM method using scikit-learn library and Evaluate the model on testing part using score and classification_report
# Create a SVM Classifier
model = SVC(kernel='linear')

# Train the model using the training sets
model.fit(X_train, y_train)

# Predict the response for test dataset
y_pred = model.predict(X_test)

# Calculate the accuracy of the model
print("Accuracy of the SVM model: ", accuracy_score(y_test, y_pred))

# Print classification report
print('Classification Report for SVM model: ')
print(classification_report(y_test, y_pred))


# Do at least two visualizations to describe or show correlations in the Glass Dataset
# Histogram of refractive index
glass_data['RI'].plot.hist(title='Histogram of Refractive Index')
plt.show()

# Scatter plot of refractive index and Ca
glass_data.plot.scatter(x='RI', y='Ca', title='Scatter plot of Refractive Index and Ca')
plt.show()

print('Which algorithm you got better accuracy? Can you justify why?')
# accuracy of Naive Bayes model:  0.3076923076923077
# accuracy of SVM model:  0.676923076923077
print('SVM model has better accuracy than Naive Bayes model. This is because SVM model tries to find the best possible decision boundary between the data points of different classes. It tries to maximize the margin between the decision boundary and the data points. On the other hand, Naive Bayes model assumes that the features are independent of each other and tries to find the probability of the data point belonging to a particular class. Hence, SVM model has better accuracy than Naive Bayes model.')
# Out:
# Accuracy of the Naive Bayes model:  0.3076923076923077
# Classification Report for Naive Bayes model:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        19
#            2       0.40      0.17      0.24        23
#            3       0.08      0.75      0.15         4
#            5       0.33      0.17      0.22         6
#            6       0.75      1.00      0.86         3
#            7       0.90      0.90      0.90        10
#
#     accuracy                           0.31        65
#    macro avg       0.41      0.50      0.40        65
# weighted avg       0.35      0.31      0.29        65
#
# Accuracy of the SVM model:  0.676923076923077
# Classification Report for SVM model:
#               precision    recall  f1-score   support
#
#            1       0.65      0.79      0.71        19
#            2       0.59      0.70      0.64        23
#            3       0.00      0.00      0.00         4
# ...
